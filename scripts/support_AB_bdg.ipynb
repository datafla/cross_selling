# %%
import pandas as pd

# %%
cubo = pd.read_excel(r"C:\Users\fdavila\OneDrive - Farmacorp S.A\Escritorio\ANALISIS -CORRELACION\data\cubo_1.xlsx", 
                    sheet_name = 'cat4',
                    skiprows=4
                    )

# %%
clusters = pd.read_excel(r"C:\Users\fdavila\OneDrive - Farmacorp S.A\Escritorio\ANALISIS -CORRELACION\data\clusters_bdg.xlsx")

# %%
clusters_fc = clusters[clusters['UNE']=='FARMACORP']

# %%
#base = pd.read_csv("Ventasxfacturas.csv")
#base.to_parquet("Ventasxfacturas.parquet", engine="fastparquet", index=False)

# %%
ventasxfact = pd.read_parquet(r"C:\Users\fdavila\OneDrive - Farmacorp S.A\Escritorio\ANALISIS -CORRELACION\data\Ventasxfacturas.parquet")

# %%
cubo['COD_ARTICULO'] = cubo['COD_ARTICULO'].astype(str)
ventasxfact['COD_ARTICULO'] = ventasxfact['COD_ARTICULO'].astype(str)

# %%
cubo_fc = pd.merge(
    cubo,
    clusters_fc,
    left_on='COD_BODEGA',
    right_on='BODEGA'
)

# %%
cubo_fc
# Out:
#                                                     CAT 4   COD_ARTICULO  \
# 0       AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO  7754734000432
# 1       AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO  7754734000432
# 2       AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO  7754734000432
# 3       AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO  7754734000432
# 4       AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO  7754734000432
# ...                                                   ...            ...
# 550557                                               YODO         370191
# 550558                                               YODO         370191
# 550559                                               YODO         370191
# 550560                                               YODO         370191
# 550561                                               YODO         370191
#
#        COD_BODEGA  Venta neta  Unidades BODEGA        UNE  \
# 0            B112      927.00         6   B112  FARMACORP
# 1            B113      154.50         1   B113  FARMACORP
# 2            B116      463.50         3   B116  FARMACORP
# 3            B195      154.50         1   B195  FARMACORP
# 4            B199      618.00         4   B199  FARMACORP
# ...           ...         ...       ...    ...        ...
# 550557       B703      117.50        15   B703  FARMACORP
# 550558       B801      102.20        14   B801  FARMACORP
# 550559       B802       70.98         9   B802  FARMACORP
# 550560       B803      352.69        45   B803  FARMACORP
# 550561       B901      320.62        41   B901  FARMACORP
#
#                                               BODEGA2      CIUDAD     REGION  \
# 0                             SC-05 CANOTO-Esq.MEXICO  Santa Cruz      LLANO
# 1                 SC-16 VILLA 1ro.DE MAYO Esq.CALLE 8  Santa Cruz      LLANO
# 2                 SC-20 VIRGEN DE COTOCA Esq.2doAnill  Santa Cruz      LLANO
# 3       SC-153 NOEL KEMPFF M. 3ER A, INT (ONCOLOGICO)  Santa Cruz      LLANO
# 4        SC-156 AV. 3ER A. EXT (Z/CONAVI HOSP OBRERO)  Santa Cruz      LLANO
# ...                                               ...         ...        ...
# 550557           BE-145 AV BOLIVAR ESQ ADOLFO VELASCO        Beni      LLANO
# 550558           PA-83 AV.09 DE FEBRERO (DIAG C/BENI)       Pando      LLANO
# 550559      PA - AV. ENRIQUE FERNANDEZ C.(P. G.BUSCH)       Pando      LLANO
# 550560           PA - AV. TAHUAMANU ESQ. 9 DE FEBRERO       Pando      LLANO
# 550561               PO-115 AV. LITORAL ESQ. CHAYANTA      Potosi  ALTIPLANO
#
#             FORMATO NSE        CLUSTER
# 0            GRANDE   B       GRANDE-B
# 1       TRADICIONAL   C  TRADICIONAL-C
# 2           MEDIANA   B      MEDIANA-B
# 3           MEDIANA   B      MEDIANA-B
# 4       TRADICIONAL   C  TRADICIONAL-C
# ...             ...  ..            ...
# 550557      MEDIANA   B      MEDIANA-B
# 550558    PERMITIDO   B    PERMITIDO-B
# 550559       GRANDE   B       GRANDE-B
# 550560       GRANDE   B       GRANDE-B
# 550561      MEDIANA   B      MEDIANA-B
#
# [550562 rows x 13 columns]

# %%
cubo_cat4 = cubo_fc[['COD_ARTICULO', 'CAT 4']].drop_duplicates()

# %%
ventasxfact = pd.merge(
  ventasxfact,
  clusters_fc,
  left_on='COD_BODEGA',
  right_on='BODEGA'
 )

# %%
# filtering only SKUs on FARMACORP
ventas_farmacia = pd.merge(cubo_cat4,
                            ventasxfact,
                            on='COD_ARTICULO',
                            how='inner'
                            )

# %%
ventas_farmacia
# Out:
#           COD_ARTICULO                                              CAT 4  \
# 0        7754734000432  AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO
# 1        7754734000432  AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO
# 2        7754734000432  AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO
# 3        7754734000432  AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO
# 4        7754734000432  AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO
# ...                ...                                                ...
# 5847968         370191                                               YODO
# 5847969         370191                                               YODO
# 5847970         370191                                               YODO
# 5847971         370191                                               YODO
# 5847972         370191                                               YODO
#
#                            FECHA COD_BODEGA NRO_FACTURAS  # Sell-OUT  Ventas  \
# 0        2025-08-11 00:00:00.000       B112   7080220S12         3.0   463.5
# 1        2025-08-22 00:00:00.000       B112   7088314S12         1.0   154.5
# 2        2025-08-26 00:00:00.000       B199    535206SCL         5.0   772.5
# 3        2025-08-28 00:00:00.000       B195    474316SCD         1.0   154.5
# 4        2025-08-30 00:00:00.000       B112   7093588S12         1.0   154.5
# ...                          ...        ...          ...         ...     ...
# 5847968  2025-10-31 00:00:00.000       B304    1254307L4         1.0     8.1
# 5847969  2025-10-31 00:00:00.000       B323    285901L23         1.0     8.1
# 5847970  2025-10-31 00:00:00.000       B402    2874837T2         1.0     8.1
# 5847971  2025-10-31 00:00:00.000       B701    2117645B1         1.0     8.1
# 5847972  2025-10-31 00:00:00.000       B802     270165P2         1.0     8.1
#
#         BODEGA        UNE                                        BODEGA2  \
# 0         B112  FARMACORP                        SC-05 CANOTO-Esq.MEXICO
# 1         B112  FARMACORP                        SC-05 CANOTO-Esq.MEXICO
# 2         B199  FARMACORP   SC-156 AV. 3ER A. EXT (Z/CONAVI HOSP OBRERO)
# 3         B195  FARMACORP  SC-153 NOEL KEMPFF M. 3ER A, INT (ONCOLOGICO)
# 4         B112  FARMACORP                        SC-05 CANOTO-Esq.MEXICO
# ...        ...        ...                                            ...
# 5847968   B304  FARMACORP          LP-63  AV.G.LANZA Esq. C/9 (ACHUMANI)
# 5847969   B323  FARMACORP         LP - AV. J.AGUIRRE ESQ C/5 (LOS PINOS)
# 5847970   B402  FARMACORP          TJ-46 AV. JAIME  PAZ Esq.EULOGIO RUIZ
# 5847971   B701  FARMACORP       BE-75 C/J.SIERRA Pza.BALLIVIAN(TRINIDAD)
# 5847972   B802  FARMACORP      PA - AV. ENRIQUE FERNANDEZ C.(P. G.BUSCH)
#
#              CIUDAD     REGION      FORMATO NSE        CLUSTER
# 0        Santa Cruz      LLANO       GRANDE   B       GRANDE-B
# 1        Santa Cruz      LLANO       GRANDE   B       GRANDE-B
# 2        Santa Cruz      LLANO  TRADICIONAL   C  TRADICIONAL-C
# 3        Santa Cruz      LLANO      MEDIANA   B      MEDIANA-B
# 4        Santa Cruz      LLANO       GRANDE   B       GRANDE-B
# ...             ...        ...          ...  ..            ...
# 5847968      La paz  ALTIPLANO      MEDIANA   A      MEDIANA-A
# 5847969      La paz  ALTIPLANO      PEQUENA   B      PEQUENA-B
# 5847970      Tarija      VALLE      MEDIANA   B      MEDIANA-B
# 5847971        Beni      LLANO       GRANDE   B       GRANDE-B
# 5847972       Pando      LLANO       GRANDE   B       GRANDE-B
#
# [5847973 rows x 15 columns]

# %% [markdown]
# ### SUPPORT A

# %%
ventasxbdg = ventas_farmacia.groupby('COD_BODEGA').agg({'NRO_FACTURAS':'nunique'}).reset_index()

# %%
ventasxbdg
# Out:
#     COD_BODEGA  NRO_FACTURAS
# 0         B101         23689
# 1         B102         27479
# 2         B104         28143
# 3         B108          9527
# 4         B109         20018
# ..         ...           ...
# 184       B703         21183
# 185       B801          9803
# 186       B802         12178
# 187       B803         27257
# 188       B901         23621
#
# [189 rows x 2 columns]

# %%
ventasxcat = ventas_farmacia.groupby(['CAT 4', 'COD_BODEGA']).agg({'NRO_FACTURAS':'nunique'}).reset_index()

# %%
ventas_cat_bdg = pd.merge(
    ventasxcat,
    ventasxbdg,
    on='COD_BODEGA',
    suffixes=('_CAT4', '_TOTAL_BDG')
)

# %%
ventas_cat_bdg
# Out:
#                                                    CAT 4 COD_BODEGA  \
# 0      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B112
# 1      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B113
# 2      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B116
# 3      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B195
# 4      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B199
# ...                                                  ...        ...
# 48720                                               YODO       B703
# 48721                                               YODO       B801
# 48722                                               YODO       B802
# 48723                                               YODO       B803
# 48724                                               YODO       B901
#
#        NRO_FACTURAS_CAT4  NRO_FACTURAS_TOTAL_BDG
# 0                      7                   39375
# 1                      1                   30869
# 2                      1                   20634
# 3                      2                    9822
# 4                      3                   16602
# ...                  ...                     ...
# 48720                 20                   21183
# 48721                 16                    9803
# 48722                 12                   12178
# 48723                 43                   27257
# 48724                 34                   23621
#
# [48725 rows x 4 columns]

# %%
ventas_cat_bdg['support_cat4'] = ventas_cat_bdg['NRO_FACTURAS_CAT4'] / ventas_cat_bdg['NRO_FACTURAS_TOTAL_BDG']

# %%
ventas_cat_bdg = ventas_cat_bdg.sort_values(by=['COD_BODEGA', 'support_cat4'], ascending=[True, False])

# %%
ventas_cat_bdg = ventas_cat_bdg.groupby('COD_BODEGA').head(50)

# %%
ventas_cat_bdg
# Out:
#                                                    CAT 4 COD_BODEGA  \
# 13555                     ANTIRREUMATICOS NO ESTEROIDEOS       B101
# 1720            ANALGESICOS NO NARCOTICOS ANTIPIRETICOS.       B101
# 9107                   ANTIGRIPALES EXC.ANTIINFARINGITIS       B101
# 26843                              HIPNOTICOS Y SEDANTES       B101
# 3412                                    ANTIACIDOS SOLOS       B101
# ...                                                  ...        ...
# 21043              CORTICOSTEROIDES TOPICOS ASOCIACIONES       B901
# 23141                                         DIURETICOS       B901
# 45996                   SUPLEMENTOS DIETARIO ALIMENTICIO       B901
# 4955   ANTIBACTERIANOS ASOCIACION TRIMETOPRIMA Y SIMI...       B901
# 35036                 OTRAS VITAMINAS SOLAS Y COMBINADAS       B901
#
#        NRO_FACTURAS_CAT4  NRO_FACTURAS_TOTAL_BDG  support_cat4
# 13555               3435                   23689      0.145004
# 1720                2908                   23689      0.122757
# 9107                2620                   23689      0.110600
# 26843               1533                   23689      0.064714
# 3412                1052                   23689      0.044409
# ...                  ...                     ...           ...
# 21043                189                   23621      0.008001
# 23141                175                   23621      0.007409
# 45996                168                   23621      0.007112
# 4955                 167                   23621      0.007070
# 35036                159                   23621      0.006731
#
# [9450 rows x 5 columns]

# %% [markdown]
# ### SUPPORT AyB

# %%
# selfmerge forfinding pairs of CAT 4 on same invoice
pairs_factura = pd.merge(
    ventas_farmacia,
    ventas_farmacia,
    on=["NRO_FACTURAS", "COD_BODEGA"],
    suffixes=("_A", "_B")
)

# filtering combinations to avoid duplicates
pairs_factura = pairs_factura[pairs_factura["CAT 4_A"] != pairs_factura["CAT 4_B"]]

# keeping only one order of each pair
pairs_factura = pairs_factura[pairs_factura["CAT 4_A"] > pairs_factura["CAT 4_B"]]

# %%
pairs_factura[['CAT 4_A', 'CAT 4_B', 'NRO_FACTURAS', 'COD_BODEGA']].shape
# Out:
# (3782749, 4)

# %%
ventasABxbdg = pairs_factura.groupby(['CAT 4_A', 'CAT 4_B', 'COD_BODEGA']).agg({'NRO_FACTURAS':'nunique'}).reset_index()

# %%
ventasABxbdg.sort_values(by=['COD_BODEGA', 'NRO_FACTURAS'], ascending=[True, False])
# Out:
#                                   CAT 4_A  \
# 112585     ANTIRREUMATICOS NO ESTEROIDEOS
# 118552     ANTIRREUMATICOS NO ESTEROIDEOS
# 56280   ANTIGRIPALES EXC.ANTIINFARINGITIS
# 242787    DESCONGESTIONANTES FARINGITICOS
# 115277     ANTIRREUMATICOS NO ESTEROIDEOS
# ...                                   ...
# 786360                               YODO
# 786420                               YODO
# 786510                               YODO
# 786517                               YODO
# 786593                               YODO
#
#                                                  CAT 4_B COD_BODEGA  \
# 112585          ANALGESICOS NO NARCOTICOS ANTIPIRETICOS.       B101
# 118552                 ANTIGRIPALES EXC.ANTIINFARINGITIS       B101
# 56280           ANALGESICOS NO NARCOTICOS ANTIPIRETICOS.       B101
# 242787                 ANTIGRIPALES EXC.ANTIINFARINGITIS       B101
# 115277       ANTIBACTERIANOS PENICILINAS AMPLIO ESPECTRO       B101
# ...                                                  ...        ...
# 786360  PRODUCTOS PARA TRATAR EL PRURITO-PICAZON EXZEMAS       B901
# 786420                     RESTAURADOR ELECTROLITOS ORAL       B901
# 786510                          SUPLEMENTOS CON MAGNESIO       B901
# 786517                  SUPLEMENTOS DIETARIO ALIMENTICIO       B901
# 786593                                        VITAMINA C       B901
#
#         NRO_FACTURAS
# 112585           373
# 118552           361
# 56280            269
# 242787           209
# 115277           197
# ...              ...
# 786360             1
# 786420             1
# 786510             1
# 786517             1
# 786593             1
#
# [786607 rows x 4 columns]

# %%
ventasxpairs = pd.merge(
    ventasABxbdg,
    ventasxbdg,
    on='COD_BODEGA',
    suffixes=('_PAIR', '_TOTAL_BDG')
)

# %%
ventasxpairs['support_AB'] = (ventasxpairs['NRO_FACTURAS_PAIR'] / ventasxpairs['NRO_FACTURAS_TOTAL_BDG']).round(8)

# %%
ventasxpairs.sort_values(by=['COD_BODEGA', 'NRO_FACTURAS_PAIR'], ascending=[True, False])
# Out:
#                                   CAT 4_A  \
# 112585     ANTIRREUMATICOS NO ESTEROIDEOS
# 118552     ANTIRREUMATICOS NO ESTEROIDEOS
# 56280   ANTIGRIPALES EXC.ANTIINFARINGITIS
# 242787    DESCONGESTIONANTES FARINGITICOS
# 115277     ANTIRREUMATICOS NO ESTEROIDEOS
# ...                                   ...
# 786360                               YODO
# 786420                               YODO
# 786510                               YODO
# 786517                               YODO
# 786593                               YODO
#
#                                                  CAT 4_B COD_BODEGA  \
# 112585          ANALGESICOS NO NARCOTICOS ANTIPIRETICOS.       B101
# 118552                 ANTIGRIPALES EXC.ANTIINFARINGITIS       B101
# 56280           ANALGESICOS NO NARCOTICOS ANTIPIRETICOS.       B101
# 242787                 ANTIGRIPALES EXC.ANTIINFARINGITIS       B101
# 115277       ANTIBACTERIANOS PENICILINAS AMPLIO ESPECTRO       B101
# ...                                                  ...        ...
# 786360  PRODUCTOS PARA TRATAR EL PRURITO-PICAZON EXZEMAS       B901
# 786420                     RESTAURADOR ELECTROLITOS ORAL       B901
# 786510                          SUPLEMENTOS CON MAGNESIO       B901
# 786517                  SUPLEMENTOS DIETARIO ALIMENTICIO       B901
# 786593                                        VITAMINA C       B901
#
#         NRO_FACTURAS_PAIR  NRO_FACTURAS_TOTAL_BDG  support_AB
# 112585                373                   23689    0.015746
# 118552                361                   23689    0.015239
# 56280                 269                   23689    0.011355
# 242787                209                   23689    0.008823
# 115277                197                   23689    0.008316
# ...                   ...                     ...         ...
# 786360                  1                   23621    0.000042
# 786420                  1                   23621    0.000042
# 786510                  1                   23621    0.000042
# 786517                  1                   23621    0.000042
# 786593                  1                   23621    0.000042
#
# [786607 rows x 6 columns]

# %%
ventas_cat_bdg_pairs = pd.merge(
    ventas_cat_bdg[['CAT 4', 'COD_BODEGA', 'NRO_FACTURAS_CAT4', 'support_cat4']],
    ventasxpairs,
    left_on=['CAT 4', 'COD_BODEGA'],
    right_on=['CAT 4_A', 'COD_BODEGA'],
    #how='left'
)

# %%
ventas_pairs = pd.merge(
    ventas_cat_bdg_pairs[['COD_BODEGA', 'NRO_FACTURAS_CAT4', 
                            'support_cat4', 'CAT 4_A','CAT 4_B', 'NRO_FACTURAS_PAIR', 
                            'NRO_FACTURAS_TOTAL_BDG', 'support_AB']],
    ventas_cat_bdg[['CAT 4', 'COD_BODEGA', 'support_cat4', 'NRO_FACTURAS_CAT4']],
    left_on=['CAT 4_B', 'COD_BODEGA'],
    right_on=['CAT 4', 'COD_BODEGA'],
    #how='left',
    suffixes=['_A', '_B']
)

# %%
ventas_pairs = ventas_pairs[[
    'COD_BODEGA', 'CAT 4_A', 'CAT 4_B', 
    'NRO_FACTURAS_CAT4_A', 'NRO_FACTURAS_CAT4_B', 'NRO_FACTURAS_PAIR', 'NRO_FACTURAS_TOTAL_BDG', 
    'support_cat4_A', 'support_cat4_B', 'support_AB',
    
]]

# %%
ventas_pairs['confidence_AB_A'] = (ventas_pairs['support_AB'] / ventas_pairs['support_cat4_A']).round(8)

# %%
ventas_pairs['lift_ABA_B'] = (ventas_pairs['confidence_AB_A'] / ventas_pairs['support_cat4_B']).round(8)

# %%
ventas_pairs = ventas_pairs.sort_values(by=['COD_BODEGA', 'support_cat4_A', 'confidence_AB_A'], ascending=[True,False, False])

# %%
ventasxcat = ventas_farmacia.groupby(['CAT 4', 'COD_BODEGA']).agg({'Ventas':'sum'}).reset_index()

# %%
ventasxcat
# Out:
#                                                    CAT 4 COD_BODEGA   Ventas
# 0      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B112  1699.50
# 1      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B113   154.50
# 2      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B116   463.50
# 3      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B195   309.00
# 4      AGENTE DEXINTOXICANTE TRATAMIENTO ANTI-NEOPLASICO       B199  1390.50
# ...                                                  ...        ...      ...
# 48720                                               YODO       B703   163.51
# 48721                                               YODO       B801   160.60
# 48722                                               YODO       B802    90.99
# 48723                                               YODO       B803   332.11
# 48724                                               YODO       B901   271.28
#
# [48725 rows x 3 columns]

# %%
ventas_pairs = pd.merge(
    ventas_pairs,
    ventasxcat,
    left_on=['CAT 4_B', 'COD_BODEGA'],
    right_on=['CAT 4', 'COD_BODEGA'],
    how='left'
)

# %%
ventas_pairs_fc = ventas_pairs[[
    'COD_BODEGA', 'CAT 4_A', 'CAT 4_B', 
    'NRO_FACTURAS_CAT4_A','NRO_FACTURAS_CAT4_B', 'NRO_FACTURAS_PAIR', 'NRO_FACTURAS_TOTAL_BDG',
    'support_cat4_A', 'support_cat4_B', 'support_AB', 'confidence_AB_A','lift_ABA_B', 'Ventas']].copy()

# %%
ventas_pairs_fc
# Out:
#        COD_BODEGA                             CAT 4_A  \
# 0            B101      ANTIRREUMATICOS NO ESTEROIDEOS
# 1            B101      ANTIRREUMATICOS NO ESTEROIDEOS
# 2            B101      ANTIRREUMATICOS NO ESTEROIDEOS
# 3            B101      ANTIRREUMATICOS NO ESTEROIDEOS
# 4            B101      ANTIRREUMATICOS NO ESTEROIDEOS
# ...           ...                                 ...
# 183572       B901  OTRAS VITAMINAS SOLAS Y COMBINADAS
# 183573       B901  OTRAS VITAMINAS SOLAS Y COMBINADAS
# 183574       B901  OTRAS VITAMINAS SOLAS Y COMBINADAS
# 183575       B901  OTRAS VITAMINAS SOLAS Y COMBINADAS
# 183576       B901  OTRAS VITAMINAS SOLAS Y COMBINADAS
#
#                                                   CAT 4_B  \
# 0                ANALGESICOS NO NARCOTICOS ANTIPIRETICOS.
# 1                       ANTIGRIPALES EXC.ANTIINFARINGITIS
# 2             ANTIBACTERIANOS PENICILINAS AMPLIO ESPECTRO
# 3                          ANTIHISTAMINICOS-ANTIALERGICOS
# 4                                        ANTIACIDOS SOLOS
# ...                                                   ...
# 183572                             ANALGESICOS NARCOTICOS
# 183573                  ANGIOTENSINA-II ANTAGONISTAS SOLO
# 183574  ANTIBACTERIANOS PENICILINAS MEDIO Y REDUCIDO E...
# 183575                                   ANTIESPASMODICOS
# 183576                 HORMONAS ANTICONCEPTIVAS SISTEMICO
#
#         NRO_FACTURAS_CAT4_A  NRO_FACTURAS_CAT4_B  NRO_FACTURAS_PAIR  \
# 0                      3435                 2908                373
# 1                      3435                 2620                361
# 2                      3435                  593                197
# 3                      3435                  655                 86
# 4                      3435                 1052                 83
# ...                     ...                  ...                ...
# 183572                  159                  281                  1
# 183573                  159                  275                  1
# 183574                  159                  194                  1
# 183575                  159                  199                  1
# 183576                  159                  396                  1
#
#         NRO_FACTURAS_TOTAL_BDG  support_cat4_A  support_cat4_B  support_AB  \
# 0                        23689        0.145004        0.122757    0.015746
# 1                        23689        0.145004        0.110600    0.015239
# 2                        23689        0.145004        0.025033    0.008316
# 3                        23689        0.145004        0.027650    0.003630
# 4                        23689        0.145004        0.044409    0.003504
# ...                        ...             ...             ...         ...
# 183572                   23621        0.006731        0.011896    0.000042
# 183573                   23621        0.006731        0.011642    0.000042
# 183574                   23621        0.006731        0.008213    0.000042
# 183575                   23621        0.006731        0.008425    0.000042
# 183576                   23621        0.006731        0.016765    0.000042
#
#         confidence_AB_A  lift_ABA_B    Ventas
# 0              0.108588    0.884574  47325.03
# 1              0.105095    0.950224  51735.93
# 2              0.057351    2.291035  21954.81
# 3              0.025036    0.905477  15373.60
# 4              0.024163    0.544105  11203.17
# ...                 ...         ...       ...
# 183572         0.006290    0.528742  11992.01
# 183573         0.006290    0.540278  12935.45
# 183574         0.006290    0.765859   9776.75
# 183575         0.006290    0.746616   5131.57
# 183576         0.006290    0.375193  24796.21
#
# [183577 rows x 13 columns]

# %%
ventas_pairs_fc.to_excel(r"C:\Users\fdavila\OneDrive - Farmacorp S.A\Escritorio\ANALISIS -CORRELACION\output\support_analysis_bdg_test.xlsx", index=False)
